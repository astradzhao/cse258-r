# %%
import pandas as pd
from sklearn.metrics import mean_squared_error
import numpy as np
from collections import defaultdict
from sklearn.model_selection import train_test_split
from itertools import product
from surprise import Dataset, Reader, SVD, accuracy
import pandas as pd

# %%
# Load the dataset
file_path = './hawaii_metadata.json.gz'
df = pd.read_json(file_path, lines=True)

df.columns
# Out:
# Index(['name', 'address', 'gmap_id', 'description', 'latitude', 'longitude',
#        'category', 'avg_rating', 'num_of_reviews', 'price', 'hours', 'MISC',
#        'state', 'relative_results', 'url'],
#       dtype='object')

# %%
df.head()
# Out:
#                           name  \
# 0                    Hale Pops
# 1  SMP - Single Marine Program
# 2                2 Cheesy Guys
# 3        Kraken Coffee Kahului
# 4        Akasatana Ramen Kyoto
#
#                                              address  \
# 0   Hale Pops, 55-370 Kamehameha Hwy, Laie, HI 96762
# 1  SMP - Single Marine Program, G St, Kailua, HI ...
# 2       2 Cheesy Guys, 1486 HI-30, Wailuku, HI 96793
# 3  Kraken Coffee Kahului, 520 Keolani Pl, Kahului...
# 4  Akasatana Ramen Kyoto, 1450 Ala Moana Blvd, Ho...
#
#                                  gmap_id description   latitude   longitude  \
# 0   0x7c00456eecad3111:0x8217f9600c51f33        None  21.637796 -157.920714
# 1  0x7c00159b5b1b1d25:0x8d2d85d4a758290e        None  21.440345 -157.754347
# 2  0x7954d376a8b12db3:0xa51dd57e1cc14ca9        None  20.853014 -156.503671
# 3  0x7954d370921ff6bd:0x3193ba783e26d032        None  20.888238 -156.450614
# 4  0x7c006df045b01715:0xe945c308688e1a46        None  21.290463 -157.843730
#
#               category  avg_rating  num_of_reviews price  \
# 0         [Restaurant]         4.4              18  None
# 1  [Recreation center]         4.1              18  None
# 2         [Food court]         5.0               6  None
# 3        [Coffee shop]         4.8               8     $
# 4   [Ramen restaurant]         5.0               1  None
#
#                                                hours  \
# 0  [[Thursday, 11AM–8PM], [Friday, 11AM–8PM], [Sa...
# 1  [[Thursday, 8AM–9PM], [Friday, 8AM–9PM], [Satu...
# 2  [[Thursday, Closed], [Friday, 11AM–6PM], [Satu...
# 3  [[Thursday, 6:30AM–7PM], [Friday, 6:30AM–7PM],...
# 4  [[Thursday, 11AM–8:30PM], [Friday, 11AM–8:30PM...
#
#                                                 MISC                    state  \
# 0  {'Service options': ['Outdoor seating', 'Takeo...      Closed ⋅ Opens 11AM
# 1  {'Accessibility': ['Wheelchair accessible entr...         Opens soon ⋅ 8AM
# 2  {'Service options': ['Curbside pickup', 'Takeo...  Closed ⋅ Opens 11AM Fri
# 3  {'Service options': ['Curbside pickup', 'No-co...        Open ⋅ Closes 7PM
# 4  {'Service options': ['Takeout', 'Dine-in', 'De...      Closed ⋅ Opens 11AM
#
#                                     relative_results  \
# 0  [0x7c00451360f80cf1:0x930291a38bab3132, 0x7c00...
# 1  [0x7c00155df23846af:0xfbe051d208292028, 0x7c00...
# 2                                               None
# 3                                               None
# 4  [0x7c006df018f6177d:0x9beb6db40fadcb2, 0x7c006...
#
#                                                  url
# 0  https://www.google.com/maps/place//data=!4m2!3...
# 1  https://www.google.com/maps/place//data=!4m2!3...
# 2  https://www.google.com/maps/place//data=!4m2!3...
# 3  https://www.google.com/maps/place//data=!4m2!3...
# 4  https://www.google.com/maps/place//data=!4m2!3...

# %%
# Split into training and temp (for validation + test)
train_df, temp_df = train_test_split(df, test_size=0.2, random_state=42)

# Split temp into validation and test
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)
test_df_baseline = test_df.copy()

# Print sizes to verify
print("Training set size:", len(train_df))
print("Validation set size:", len(val_df))
print("Test set size:", len(test_df))
